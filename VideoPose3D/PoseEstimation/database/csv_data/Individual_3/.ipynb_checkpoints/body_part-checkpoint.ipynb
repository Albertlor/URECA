# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('left_hand_dict_json.csv')
df_T = df.T
df_T
# Out:
#                       0         1         2
# LEFT_HAND_1   -0.216780  0.065880 -0.003128
# LEFT_HAND_2   -0.218130  0.065594 -0.003026
# LEFT_HAND_3   -0.219805  0.066066 -0.000991
# LEFT_HAND_4   -0.221717  0.066972 -0.005259
# LEFT_HAND_5   -0.223620  0.068284 -0.007506
# ...                 ...       ...       ...
# LEFT_HAND_251 -0.219212  0.072299  0.099902
# LEFT_HAND_252 -0.219631  0.071745  0.102098
# LEFT_HAND_253 -0.219621  0.073262  0.098064
# LEFT_HAND_254 -0.220065  0.073938  0.094323
# LEFT_HAND_255 -0.219433  0.073558  0.091177
#
# [255 rows x 3 columns]

# %%
df_T.columns = ['x', 'y', 'z']
df_T
# Out:
#                       x         y         z
# LEFT_HAND_1   -0.216780  0.065880 -0.003128
# LEFT_HAND_2   -0.218130  0.065594 -0.003026
# LEFT_HAND_3   -0.219805  0.066066 -0.000991
# LEFT_HAND_4   -0.221717  0.066972 -0.005259
# LEFT_HAND_5   -0.223620  0.068284 -0.007506
# ...                 ...       ...       ...
# LEFT_HAND_251 -0.219212  0.072299  0.099902
# LEFT_HAND_252 -0.219631  0.071745  0.102098
# LEFT_HAND_253 -0.219621  0.073262  0.098064
# LEFT_HAND_254 -0.220065  0.073938  0.094323
# LEFT_HAND_255 -0.219433  0.073558  0.091177
#
# [255 rows x 3 columns]

# %%
frame = []
for i in range(255):
    frame.append(i+1)
frame_col = pd.DataFrame(frame)
frame_col.columns = ['frame']
frame_col
# Out:
#      frame
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
# ..     ...
# 250    251
# 251    252
# 252    253
# 253    254
# 254    255
#
# [255 rows x 1 columns]

# %%
df_T.index = frame_col.index
new_df = pd.concat([df_T, frame_col], axis=1)
new_df
# Out:
#             x         y         z  frame
# 0   -0.216780  0.065880 -0.003128      1
# 1   -0.218130  0.065594 -0.003026      2
# 2   -0.219805  0.066066 -0.000991      3
# 3   -0.221717  0.066972 -0.005259      4
# 4   -0.223620  0.068284 -0.007506      5
# ..        ...       ...       ...    ...
# 250 -0.219212  0.072299  0.099902    251
# 251 -0.219631  0.071745  0.102098    252
# 252 -0.219621  0.073262  0.098064    253
# 253 -0.220065  0.073938  0.094323    254
# 254 -0.219433  0.073558  0.091177    255
#
# [255 rows x 4 columns]

# %%
col1 = new_df[['x', 'frame']]
col1_df = pd.DataFrame(data=col1)
col1_df
# Out:
#             x  frame
# 0   -0.216780      1
# 1   -0.218130      2
# 2   -0.219805      3
# 3   -0.221717      4
# 4   -0.223620      5
# ..        ...    ...
# 250 -0.219212    251
# 251 -0.219631    252
# 252 -0.219621    253
# 253 -0.220065    254
# 254 -0.219433    255
#
# [255 rows x 2 columns]

# %%
col2 = new_df[['y', 'frame']]
col2_df = pd.DataFrame(data=col2)
col2_df
# Out:
#             y  frame
# 0    0.065880      1
# 1    0.065594      2
# 2    0.066066      3
# 3    0.066972      4
# 4    0.068284      5
# ..        ...    ...
# 250  0.072299    251
# 251  0.071745    252
# 252  0.073262    253
# 253  0.073938    254
# 254  0.073558    255
#
# [255 rows x 2 columns]

# %%
col3 = new_df[['z', 'frame']]
col3_df = pd.DataFrame(data=col3)
col3_df
# Out:
#             z  frame
# 0   -0.003128      1
# 1   -0.003026      2
# 2   -0.000991      3
# 3   -0.005259      4
# 4   -0.007506      5
# ..        ...    ...
# 250  0.099902    251
# 251  0.102098    252
# 252  0.098064    253
# 253  0.094323    254
# 254  0.091177    255
#
# [255 rows x 2 columns]

# %%
cols = ['x', 'y', 'z']

f, axes = plt.subplots(1, 3, figsize=(18, 5))
axes[0].set_ylim(-1.7, 1.7)
axes[1].set_ylim(-1.7, 1.7)
axes[2].set_ylim(0, 3.4)

list = ['x', 'y', 'z']
count = 0
for col in cols:
    sb.scatterplot(x=new_df['frame'], y=new_df[col], ax = axes[count])
    count += 1
