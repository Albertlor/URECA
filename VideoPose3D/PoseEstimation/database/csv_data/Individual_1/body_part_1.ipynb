# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('upper_torso_dict_json.csv')
df_T = df.T
df_T
# Out:
#                         0         1         2
# UPPER_TORSO_1   -0.010478 -0.469369 -0.080588
# UPPER_TORSO_2   -0.010565 -0.469342 -0.080376
# UPPER_TORSO_3   -0.010298 -0.469119 -0.080304
# UPPER_TORSO_4   -0.010285 -0.468883 -0.080131
# UPPER_TORSO_5   -0.009633 -0.468551 -0.080053
# ...                   ...       ...       ...
# UPPER_TORSO_237 -0.006230 -0.466329 -0.095686
# UPPER_TORSO_238 -0.006848 -0.466680 -0.093903
# UPPER_TORSO_239 -0.007706 -0.467077 -0.092107
# UPPER_TORSO_240 -0.008149 -0.466994 -0.091964
# UPPER_TORSO_241 -0.008081 -0.467050 -0.091896
#
# [241 rows x 3 columns]

# %%
df_T.columns = ['x', 'y', 'z']
df_T
# Out:
#                         x         y         z
# UPPER_TORSO_1   -0.010478 -0.469369 -0.080588
# UPPER_TORSO_2   -0.010565 -0.469342 -0.080376
# UPPER_TORSO_3   -0.010298 -0.469119 -0.080304
# UPPER_TORSO_4   -0.010285 -0.468883 -0.080131
# UPPER_TORSO_5   -0.009633 -0.468551 -0.080053
# ...                   ...       ...       ...
# UPPER_TORSO_237 -0.006230 -0.466329 -0.095686
# UPPER_TORSO_238 -0.006848 -0.466680 -0.093903
# UPPER_TORSO_239 -0.007706 -0.467077 -0.092107
# UPPER_TORSO_240 -0.008149 -0.466994 -0.091964
# UPPER_TORSO_241 -0.008081 -0.467050 -0.091896
#
# [241 rows x 3 columns]

# %%
frame = []
for i in range(241):
    frame.append(i+1)
frame_col = pd.DataFrame(frame)
frame_col.columns = ['frame']
frame_col
# Out:
#      frame
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
# ..     ...
# 236    237
# 237    238
# 238    239
# 239    240
# 240    241
#
# [241 rows x 1 columns]

# %%
df_T.index = frame_col.index
new_df = pd.concat([df_T, frame_col], axis=1)
new_df
# Out:
#             x         y         z  frame
# 0   -0.010478 -0.469369 -0.080588      1
# 1   -0.010565 -0.469342 -0.080376      2
# 2   -0.010298 -0.469119 -0.080304      3
# 3   -0.010285 -0.468883 -0.080131      4
# 4   -0.009633 -0.468551 -0.080053      5
# ..        ...       ...       ...    ...
# 236 -0.006230 -0.466329 -0.095686    237
# 237 -0.006848 -0.466680 -0.093903    238
# 238 -0.007706 -0.467077 -0.092107    239
# 239 -0.008149 -0.466994 -0.091964    240
# 240 -0.008081 -0.467050 -0.091896    241
#
# [241 rows x 4 columns]

# %%
col1 = new_df[['x', 'frame']]
col1_df = pd.DataFrame(data=col1)
col1_df
# Out:
#             x  frame
# 0   -0.010478      1
# 1   -0.010565      2
# 2   -0.010298      3
# 3   -0.010285      4
# 4   -0.009633      5
# ..        ...    ...
# 236 -0.006230    237
# 237 -0.006848    238
# 238 -0.007706    239
# 239 -0.008149    240
# 240 -0.008081    241
#
# [241 rows x 2 columns]

# %%
col2 = new_df[['y', 'frame']]
col2_df = pd.DataFrame(data=col2)
col2_df
# Out:
#             y  frame
# 0   -0.469369      1
# 1   -0.469342      2
# 2   -0.469119      3
# 3   -0.468883      4
# 4   -0.468551      5
# ..        ...    ...
# 236 -0.466329    237
# 237 -0.466680    238
# 238 -0.467077    239
# 239 -0.466994    240
# 240 -0.467050    241
#
# [241 rows x 2 columns]

# %%
col3 = new_df[['z', 'frame']]
col3_df = pd.DataFrame(data=col3)
col3_df
# Out:
#             z  frame
# 0   -0.080588      1
# 1   -0.080376      2
# 2   -0.080304      3
# 3   -0.080131      4
# 4   -0.080053      5
# ..        ...    ...
# 236 -0.095686    237
# 237 -0.093903    238
# 238 -0.092107    239
# 239 -0.091964    240
# 240 -0.091896    241
#
# [241 rows x 2 columns]

# %%
cols = ['x', 'y', 'z']

f, axes = plt.subplots(1, 3, figsize=(18, 5))
axes[0].set_ylim(-1.7, 1.7)
axes[1].set_ylim(-1.7, 1.7)
axes[2].set_ylim(-1.7, 1.7)

list = ['x', 'y', 'z']
count = 0
for col in cols:
    sb.scatterplot(x=new_df['frame'], y=new_df[col], ax = axes[count])
    count += 1
