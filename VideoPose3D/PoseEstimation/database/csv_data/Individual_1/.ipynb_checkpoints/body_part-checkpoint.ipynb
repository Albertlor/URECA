# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('left_shoulder_dict_json.csv')
df_T = df.T
df_T
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_41384/2994180131.py in <module>
# ----> 1 df = pd.read_csv('left_shoulder_dict_json.csv')
#       2 df_T = df.T
#       3 df_T
#
# NameError: name 'pd' is not defined

# %%
df_T.columns = ['x', 'y', 'z']
df_T
# Out:
#                           x         y         z
# LEFT_SHOULDER_1   -0.099448 -0.379805 -0.147127
# LEFT_SHOULDER_2   -0.099062 -0.379496 -0.147251
# LEFT_SHOULDER_3   -0.098664 -0.379022 -0.147189
# LEFT_SHOULDER_4   -0.098514 -0.378736 -0.147148
# LEFT_SHOULDER_5   -0.097680 -0.378282 -0.147322
# ...                     ...       ...       ...
# LEFT_SHOULDER_237 -0.080612 -0.370694 -0.171250
# LEFT_SHOULDER_238 -0.080728 -0.370909 -0.169510
# LEFT_SHOULDER_239 -0.081193 -0.371089 -0.167467
# LEFT_SHOULDER_240 -0.081073 -0.370713 -0.167389
# LEFT_SHOULDER_241 -0.081224 -0.370520 -0.167397
#
# [241 rows x 3 columns]

# %%
frame = []
for i in range(241):
    frame.append(i+1)
frame_col = pd.DataFrame(frame)
frame_col.columns = ['frame']
frame_col
# Out:
#      frame
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
# ..     ...
# 236    237
# 237    238
# 238    239
# 239    240
# 240    241
#
# [241 rows x 1 columns]

# %%
df_T.index = frame_col.index
new_df = pd.concat([df_T, frame_col], axis=1)
new_df
# Out:
#             x         y         z  frame
# 0   -0.099448 -0.379805 -0.147127      1
# 1   -0.099062 -0.379496 -0.147251      2
# 2   -0.098664 -0.379022 -0.147189      3
# 3   -0.098514 -0.378736 -0.147148      4
# 4   -0.097680 -0.378282 -0.147322      5
# ..        ...       ...       ...    ...
# 236 -0.080612 -0.370694 -0.171250    237
# 237 -0.080728 -0.370909 -0.169510    238
# 238 -0.081193 -0.371089 -0.167467    239
# 239 -0.081073 -0.370713 -0.167389    240
# 240 -0.081224 -0.370520 -0.167397    241
#
# [241 rows x 4 columns]

# %%
col1 = new_df[['x', 'frame']]
col1_df = pd.DataFrame(data=col1)
col1_df
# Out:
#             x  frame
# 0   -0.099448      1
# 1   -0.099062      2
# 2   -0.098664      3
# 3   -0.098514      4
# 4   -0.097680      5
# ..        ...    ...
# 236 -0.080612    237
# 237 -0.080728    238
# 238 -0.081193    239
# 239 -0.081073    240
# 240 -0.081224    241
#
# [241 rows x 2 columns]

# %%
col2 = new_df[['y', 'frame']]
col2_df = pd.DataFrame(data=col2)
col2_df
# Out:
#             y  frame
# 0   -0.379805      1
# 1   -0.379496      2
# 2   -0.379022      3
# 3   -0.378736      4
# 4   -0.378282      5
# ..        ...    ...
# 236 -0.370694    237
# 237 -0.370909    238
# 238 -0.371089    239
# 239 -0.370713    240
# 240 -0.370520    241
#
# [241 rows x 2 columns]

# %%
col3 = new_df[['z', 'frame']]
col3_df = pd.DataFrame(data=col3)
col3_df
# Out:
#             z  frame
# 0   -0.147127      1
# 1   -0.147251      2
# 2   -0.147189      3
# 3   -0.147148      4
# 4   -0.147322      5
# ..        ...    ...
# 236 -0.171250    237
# 237 -0.169510    238
# 238 -0.167467    239
# 239 -0.167389    240
# 240 -0.167397    241
#
# [241 rows x 2 columns]

# %%
cols = ['x', 'y', 'z']

f, axes = plt.subplots(1, 3, figsize=(18, 5))
axes[0].set_ylim(-1.7, 1.7)
axes[1].set_ylim(-1.7, 1.7)
axes[2].set_ylim(0, 3.4)

list = ['x', 'y', 'z']
count = 0
for col in cols:
    sb.scatterplot(x=new_df['frame'], y=new_df[col], ax = axes[count])
    count += 1
