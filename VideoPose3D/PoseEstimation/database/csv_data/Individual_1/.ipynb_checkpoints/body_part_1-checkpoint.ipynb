# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('left_hand_dict_json.csv')
df_T = df.T
df_T
# Out:
#                       0         1         2
# LEFT_HAND_1   -0.105797  0.123960 -0.167918
# LEFT_HAND_2   -0.103372  0.124058 -0.168578
# LEFT_HAND_3   -0.101606  0.124719 -0.168740
# LEFT_HAND_4   -0.099577  0.125135 -0.169851
# LEFT_HAND_5   -0.096769  0.125807 -0.171638
# ...                 ...       ...       ...
# LEFT_HAND_237  0.000958  0.125745 -0.214198
# LEFT_HAND_238  0.001425  0.125408 -0.212925
# LEFT_HAND_239  0.001261  0.125441 -0.211738
# LEFT_HAND_240  0.001094  0.126229 -0.208985
# LEFT_HAND_241  0.000242  0.126706 -0.206957
#
# [241 rows x 3 columns]

# %%
df_T.columns = ['x', 'y', 'z']
df_T
# Out:
#                       x         y         z
# LEFT_HAND_1   -0.105797  0.123960 -0.167918
# LEFT_HAND_2   -0.103372  0.124058 -0.168578
# LEFT_HAND_3   -0.101606  0.124719 -0.168740
# LEFT_HAND_4   -0.099577  0.125135 -0.169851
# LEFT_HAND_5   -0.096769  0.125807 -0.171638
# ...                 ...       ...       ...
# LEFT_HAND_237  0.000958  0.125745 -0.214198
# LEFT_HAND_238  0.001425  0.125408 -0.212925
# LEFT_HAND_239  0.001261  0.125441 -0.211738
# LEFT_HAND_240  0.001094  0.126229 -0.208985
# LEFT_HAND_241  0.000242  0.126706 -0.206957
#
# [241 rows x 3 columns]

# %%
frame = []
for i in range(241):
    frame.append(i+1)
frame_col = pd.DataFrame(frame)
frame_col.columns = ['frame']
frame_col
# Out:
#      frame
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
# ..     ...
# 236    237
# 237    238
# 238    239
# 239    240
# 240    241
#
# [241 rows x 1 columns]

# %%
df_T.index = frame_col.index
new_df = pd.concat([df_T, frame_col], axis=1)
new_df
# Out:
#             x         y         z  frame
# 0   -0.105797  0.123960 -0.167918      1
# 1   -0.103372  0.124058 -0.168578      2
# 2   -0.101606  0.124719 -0.168740      3
# 3   -0.099577  0.125135 -0.169851      4
# 4   -0.096769  0.125807 -0.171638      5
# ..        ...       ...       ...    ...
# 236  0.000958  0.125745 -0.214198    237
# 237  0.001425  0.125408 -0.212925    238
# 238  0.001261  0.125441 -0.211738    239
# 239  0.001094  0.126229 -0.208985    240
# 240  0.000242  0.126706 -0.206957    241
#
# [241 rows x 4 columns]

# %%
col1 = new_df[['x', 'frame']]
col1_df = pd.DataFrame(data=col1)
col1_df
# Out:
#             x  frame
# 0   -0.105797      1
# 1   -0.103372      2
# 2   -0.101606      3
# 3   -0.099577      4
# 4   -0.096769      5
# ..        ...    ...
# 236  0.000958    237
# 237  0.001425    238
# 238  0.001261    239
# 239  0.001094    240
# 240  0.000242    241
#
# [241 rows x 2 columns]

# %%
col2 = new_df[['y', 'frame']]
col2_df = pd.DataFrame(data=col2)
col2_df
# Out:
#             y  frame
# 0    0.123960      1
# 1    0.124058      2
# 2    0.124719      3
# 3    0.125135      4
# 4    0.125807      5
# ..        ...    ...
# 236  0.125745    237
# 237  0.125408    238
# 238  0.125441    239
# 239  0.126229    240
# 240  0.126706    241
#
# [241 rows x 2 columns]

# %%
col3 = new_df[['z', 'frame']]
col3_df = pd.DataFrame(data=col3)
col3_df
# Out:
#             z  frame
# 0   -0.167918      1
# 1   -0.168578      2
# 2   -0.168740      3
# 3   -0.169851      4
# 4   -0.171638      5
# ..        ...    ...
# 236 -0.214198    237
# 237 -0.212925    238
# 238 -0.211738    239
# 239 -0.208985    240
# 240 -0.206957    241
#
# [241 rows x 2 columns]

# %%
cols = ['x', 'y', 'z']

f, axes = plt.subplots(1, 3, figsize=(18, 5))
axes[0].set_ylim(-1.7, 1.7)
axes[1].set_ylim(-1.7, 1.7)
axes[2].set_ylim(-1.7, 1.7)

list = ['x', 'y', 'z']
count = 0
for col in cols:
    sb.scatterplot(x=new_df['frame'], y=new_df[col], ax = axes[count])
    count += 1
