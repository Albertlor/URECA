# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('left_shoulder_dict_json.csv')
df_T = df.T
df_T
# Out:
#                           0         1         2
# RIGHT_SHOULDER_1   0.145122 -0.370801 -0.145652
# RIGHT_SHOULDER_2   0.143982 -0.371045 -0.146102
# RIGHT_SHOULDER_3   0.142732 -0.371288 -0.146423
# RIGHT_SHOULDER_4   0.141084 -0.371761 -0.147674
# RIGHT_SHOULDER_5   0.140412 -0.371777 -0.148841
# ...                     ...       ...       ...
# RIGHT_SHOULDER_58  0.142599 -0.369895 -0.143561
# RIGHT_SHOULDER_59  0.143786 -0.370231 -0.141003
# RIGHT_SHOULDER_60  0.144482 -0.370281 -0.139163
# RIGHT_SHOULDER_61  0.145016 -0.370561 -0.137404
# RIGHT_SHOULDER_62  0.145393 -0.370809 -0.135323
#
# [62 rows x 3 columns]

# %%
df_T.columns = ['x', 'y', 'z']
df_T
# Out:
#                       x         y         z
# RIGHT_HAND_1  -0.271990  0.031944 -0.026894
# RIGHT_HAND_2  -0.273400  0.032692 -0.032287
# RIGHT_HAND_3  -0.274061  0.033119 -0.040058
# RIGHT_HAND_4  -0.273745  0.033313 -0.046085
# RIGHT_HAND_5  -0.274588  0.035696 -0.047736
# ...                 ...       ...       ...
# RIGHT_HAND_58 -0.284294  0.031797 -0.058330
# RIGHT_HAND_59 -0.282324  0.032006 -0.054854
# RIGHT_HAND_60 -0.281179  0.032059 -0.049089
# RIGHT_HAND_61 -0.278071  0.032981 -0.043908
# RIGHT_HAND_62 -0.275696  0.033817 -0.042651
#
# [62 rows x 3 columns]

# %%
frame = []
for i in range(62):
    frame.append(i+1)
frame_col = pd.DataFrame(frame)
frame_col.columns = ['frame']
frame_col
# Out:
#     frame
# 0       1
# 1       2
# 2       3
# 3       4
# 4       5
# ..    ...
# 57     58
# 58     59
# 59     60
# 60     61
# 61     62
#
# [62 rows x 1 columns]

# %%
df_T.index = frame_col.index
new_df = pd.concat([df_T, frame_col], axis=1)
new_df
# Out:
#            x         y         z  frame
# 0  -0.271990  0.031944 -0.026894      1
# 1  -0.273400  0.032692 -0.032287      2
# 2  -0.274061  0.033119 -0.040058      3
# 3  -0.273745  0.033313 -0.046085      4
# 4  -0.274588  0.035696 -0.047736      5
# ..       ...       ...       ...    ...
# 57 -0.284294  0.031797 -0.058330     58
# 58 -0.282324  0.032006 -0.054854     59
# 59 -0.281179  0.032059 -0.049089     60
# 60 -0.278071  0.032981 -0.043908     61
# 61 -0.275696  0.033817 -0.042651     62
#
# [62 rows x 4 columns]

# %%
col1 = new_df[['x', 'frame']]
col1_df = pd.DataFrame(data=col1)
col1_df
# Out:
#            x  frame
# 0  -0.271990      1
# 1  -0.273400      2
# 2  -0.274061      3
# 3  -0.273745      4
# 4  -0.274588      5
# ..       ...    ...
# 57 -0.284294     58
# 58 -0.282324     59
# 59 -0.281179     60
# 60 -0.278071     61
# 61 -0.275696     62
#
# [62 rows x 2 columns]

# %%
col2 = new_df[['y', 'frame']]
col2_df = pd.DataFrame(data=col2)
col2_df
# Out:
#            y  frame
# 0   0.031944      1
# 1   0.032692      2
# 2   0.033119      3
# 3   0.033313      4
# 4   0.035696      5
# ..       ...    ...
# 57  0.031797     58
# 58  0.032006     59
# 59  0.032059     60
# 60  0.032981     61
# 61  0.033817     62
#
# [62 rows x 2 columns]

# %%
col3 = new_df[['z', 'frame']]
col3_df = pd.DataFrame(data=col3)
col3_df
# Out:
#            z  frame
# 0  -0.026894      1
# 1  -0.032287      2
# 2  -0.040058      3
# 3  -0.046085      4
# 4  -0.047736      5
# ..       ...    ...
# 57 -0.058330     58
# 58 -0.054854     59
# 59 -0.049089     60
# 60 -0.043908     61
# 61 -0.042651     62
#
# [62 rows x 2 columns]

# %%
cols = ['x', 'y', 'z']

f, axes = plt.subplots(1, 3, figsize=(18, 5))
axes[0].set_ylim(-1.7, 1.7)
axes[1].set_ylim(-1.7, 1.7)
axes[2].set_ylim(-1.7, 1.7)

list = ['x', 'y', 'z']
count = 0
for col in cols:
    sb.scatterplot(x=new_df['frame'], y=new_df[col], ax = axes[count])
    count += 1
